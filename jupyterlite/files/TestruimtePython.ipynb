# %% [markdown]
# ## Opdracht 1 – Print getallen
#
# Schrijf een programma dat de getallen 1 t/m 5 print.
# Gebruik een `for`-loop.

# %%
## Typ hier je code

# === leerlingcode ===
output = []

for i in range(5):
    output.append(i)

print(output)

# %%
# === AI context builder (Python ONLY) ===
import json

task_md = """
Schrijf een programma dat de getallen 1 t/m 5 print.
Gebruik een for-loop.
"""

student_code = """
for i in range(5):
    output.append(i)
"""

try:
    student_output = str(output)
except NameError:
    student_output = "No output yet. Student code not executed."

context = {
    "task_md": task_md,
    "language": "python",
    "code": student_code,
    "output": student_output,
    "level": "beginner",
    "mode": "hint"
}

# IMPORTANT: print REAL JSON (not Python dict)
print(json.dumps(context))

# %%
# %%html
# <script>
# (async () => {
#   const pres = document.querySelectorAll("pre");
#   const last = pres[pres.length - 1];
#
#   if (!last) {
#     alert("No Python output found. Run the context cell first.");
#     return;
#   }
#
#   const context = JSON.parse(last.innerText);
#
#   const response = await fetch(
#     "https://ai-coach-backend-0jqg.onrender.com/api/hint",
#     {
#       method: "POST",
#       headers: { "Content-Type": "application/json" },
#       body: JSON.stringify(context)
#     }
#   );
#
#   const data = await response.json();
#   alert(data.text || JSON.stringify(data));
# })();
# </script>
